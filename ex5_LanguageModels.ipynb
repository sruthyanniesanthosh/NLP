# %% [markdown]
# # Language Models

# %% [markdown]
# In the following we make some basic implementations of n-gram language models, a few simple smoothing methods and train and evaluate our models on a small corpus and finally build a small application.
#
# Let us start with a class to store n-gram counts. We have to store the counts for many word sequences (n grams) and should be able to retrieve them efficiently. Here we use a prefix tree for this purpose.

# %%
from  collections import Counter

class node:
    count = 0
    branches = {}
    
    def __init__(self):
        self.count = 0
        self.branches = {}
    
class ngramcounts:
    
    tree = node()
    maxlen = 0
    
    def __init__(self):
        self.tree = node()
    
    def add(self,words,amount=1):
        if len(words) > self.maxlen:
            self.maxlen = len(words)
        current = self.tree
        current.count += amount
        for w in words:
            nxt = current.branches.get(w,node())
            nxt.count += amount
            current.branches[w] = nxt
            current = nxt
            
    def getcount(self,words):
        current = self.tree
        for w in words:
            current = current.branches.get(w.lower(),node())
            if current.count == 0:
                break
        return current.count
    
    def getsuccessors(self,words):
        current = self.tree
        for w in words:
            current = current.branches.get(w,node())
            if current.count == 0:
                break
        successors = current.branches
        return Counter({w:successors[w].count for w in successors})
    
    def allngrams(self,maxdepth):
        stack = []
        ng =[]
        for word in self.tree.branches:
            ndword = self.tree.branches[word]
            stack.append(([word],ndword.count,ndword.branches))
        
        while len(stack) > 0:
            ng,cnt,tree = stack[-1]
            yield(ng,cnt)
            stack = stack[:-1]
            if len(ng) < maxdepth:
                for word in tree:
                    n = tree[word]
                    stack.append((ng+[word],n.count,n.branches))

# %% [markdown]
# #### Testing the class
#
# Let us just write some code to test the class

# %%
test = ngramcounts()
test.add(['a','b','c'],2)
test.add(['a','b','d'])
test.add(['b','d','e'])

# %%
for ng in test.allngrams(3):
    print(ng)
# Out:
# (['b'], 1)
# (['b', 'd'], 1)
# (['b', 'd', 'e'], 1)
# (['a'], 3)
# (['a', 'b'], 3)
# (['a', 'b', 'd'], 1)
# (['a', 'b', 'c'], 2)

# %%
for ng in test.allngrams(2):
    print(ng)
# Out:
# (['b'], 1)
# (['b', 'd'], 1)
# (['a'], 3)
# (['a', 'b'], 3)

# %%
test.getcount(['a','b'])
# Out:
# 3

# %%
test.getsuccessors(['a','b'])
# Out:
# Counter({'c': 2, 'd': 1})

# %%
test.getsuccessors([])
# Out:
# Counter({'a': 3, 'b': 1})

# %% [markdown]
# ## Read n-Grams from a Corpus
#
# We see a corpus as one long list of words. We use a sliding window to collect n-grams. In this way we might loss some shorter sequences at the beginning and the end. For a corpus of 1 Mio words this is, however, neglectible.

# %%
from collections import deque

def collect_ngram(words,n):
    counts = ngramcounts()
    last_n = deque([],n)
    for w in words:
        w = w.lower()
        last_n.append(w)
        if len(last_n) == n:
            counts.add(list(last_n))
    return counts

# %% [markdown]
# We use the Brown corpus that is available in the NLTK. Eventually you have to download this first. We excluse the firts 10,000 words. So we can use this part later for testing. Since the corpus is sorted over text genres, this is not the split that will give us the best results, but still better results than a test on a completely different corpus!

# %%
import nltk

nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/sruthysanthosh/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
from nltk.corpus import brown

len(brown.words())
# Out:
# 1161192

# %%
ngram_cnt = collect_ngram(brown.words()[10000:],4)

# %% [markdown]
# Let us have a look at the colleted counts in order to see wheter we have plausible data and nothing went wrong.

# %%
ngram_cnt.getcount(['the','old','testament'])
# Out:
# 5

# %%
ngram_cnt.getsuccessors(['the','old']).most_common()
# Out:
# [('man', 36),
#  ('woman', 10),
#  ('days', 7),
#  ('testament', 5),
#  ('chinese', 5),
#  ('south', 4),
#  ('church', 4),
#  ('west', 3),
#  ('school', 3),
#  ('southern', 3),
#  ('order', 3),
#  ('lady', 3),
#  ('ones', 3),
#  ("man's", 3),
#  ('phrase', 2),
#  ('grad', 2),
#  ('story', 2),
#  ('house', 2),
#  ('way', 2),
#  ('roman', 2),
#  (',', 2),
#  ('monk', 2),
#  ('country', 2),
#  ('town', 1),
#  ('``', 1),
#  ('vic', 1),
#  ('picker', 1),
#  ('chisholm', 1),
#  ('silent', 1),
#  ('adam', 1),
#  ('suffrage', 1),
#  ('resolve', 1),
#  ('couples', 1),
#  ('injury', 1),
#  ('new', 1),
#  ('type', 1),
#  ('scenes', 1),
#  ('paths', 1),
#  ('campus', 1),
#  ('player', 1),
#  ('under', 1),
#  ('boy', 1),
#  ('production', 1),
#  ('war', 1),
#  ('eighteenth-century', 1),
#  ('plays', 1),
#  ('tradition', 1),
#  ('consummate', 1),
#  ('mind', 1),
#  ('puritan', 1),
#  ('interest', 1),
#  ('remington', 1),
#  ('model', 1),
#  ('wells', 1),
#  ('whaling', 1),
#  ('frontier', 1),
#  ('section', 1),
#  ('covered', 1),
#  ('bridge', 1),
#  ('beverly', 1),
#  ('john', 1),
#  ('stand', 1),
#  ('established', 1),
#  ('shop', 1),
#  ('right', 1),
#  ('harbor', 1),
#  ('fogy', 1),
#  ('paints', 1),
#  ('bolsheviks', 1),
#  ('irish', 1),
#  ('battle', 1),
#  ('city', 1),
#  ('servants', 1),
#  ('belasco', 1),
#  ('custom', 1),
#  ('frontiersmen', 1),
#  ('temple', 1),
#  ('unreconstructed', 1),
#  ('splendor', 1),
#  ('caravan', 1),
#  ('kajar', 1),
#  ('life', 1),
#  ('jeffersonians', 1),
#  ('panorama', 1),
#  ('families', 1),
#  ('swedish', 1),
#  ('happy', 1),
#  ('structures', 1),
#  ('problem', 1),
#  ('forms', 1),
#  ('masters', 1),
#  ('song', 1),
#  ('and', 1),
#  ('.', 1),
#  ('ideal', 1),
#  ('sensuous', 1),
#  ('mercer', 1),
#  ('mayans', 1),
#  ('blues', 1),
#  ('method', 1),
#  ('name', 1),
#  ('nest', 1),
#  ('colony', 1),
#  ('diversity', 1),
#  ('dominion', 1),
#  ('syntax', 1),
#  ('garnett', 1),
#  ('trapper', 1),
#  ('morse', 1),
#  ('factory', 1),
#  ('store', 1),
#  ("shepherd's", 1),
#  ('literature', 1),
#  ('preacher', 1),
#  ('members', 1),
#  ('clubhouse', 1),
#  ('anxiety', 1),
#  ('portraits', 1),
#  ('aunt', 1),
#  ('familiarness', 1),
#  ('girl', 1),
#  ('plymouth', 1),
#  ('newspaper', 1),
#  ('jail', 1),
#  ("woman's", 1),
#  ('neighborhood', 1),
#  ('bastard', 1),
#  ('gal', 1),
#  ('dogtown', 1),
#  ('maps', 1),
#  ('records', 1),
#  ('norberg', 1),
#  ("master's", 1),
#  ('haskell', 1),
#  ('vaquero', 1),
#  ('taboo', 1),
#  ('mexican', 1),
#  ('french', 1),
#  ('horsehair', 1),
#  ('one', 1),
#  ('fool', 1),
#  ('coal', 1),
#  ('sacred', 1),
#  ('images', 1),
#  ('fellow', 1),
#  ('nightmare', 1)]

# %%
ngram_cnt.getsuccessors([]).most_common()
# Out:
# [('the', 69296),
#  (',', 57930),
#  ('.', 48969),
#  ('of', 36097),
#  ('and', 28679),
#  ('to', 25893),
#  ('a', 22988),
#  ('in', 21142),
#  ('that', 10495),
#  ('is', 10054),
#  ('was', 9754),
#  ('he', 9477),
#  ('for', 9379),
#  ('``', 8734),
#  ('it', 8707),
#  ("''", 8690),
#  ('with', 7254),
#  ('as', 7200),
#  ('his', 6961),
#  ('on', 6673),
#  ('be', 6308),
#  (';', 5564),
#  ('at', 5342),
#  ('by', 5235),
#  ('i', 5157),
#  ('had', 5113),
#  ('this', 5108),
#  ('?', 4689),
#  ('not', 4575),
#  ('are', 4375),
#  ('but', 4359),
#  ('from', 4345),
#  ('or', 4184),
#  ('have', 3918),
#  ('an', 3706),
#  ('they', 3604),
#  ('which', 3531),
#  ('--', 3410),
#  ('you', 3282),
#  ('one', 3268),
#  ('were', 3267),
#  ('her', 3036),
#  ('all', 2993),
#  ('she', 2860),
#  ('there', 2701),
#  ('their', 2658),
#  ('we', 2649),
#  ('would', 2634),
#  ('him', 2618),
#  (')', 2451),
#  ('been', 2438),
#  ('(', 2420),
#  ('has', 2389),
#  ('when', 2321),
#  ('who', 2227),
#  ('will', 2209),
#  ('more', 2190),
#  ('if', 2187),
#  ('no', 2123),
#  ('out', 2084),
#  ('so', 1980),
#  ('what', 1902),
#  ('said', 1885),
#  ('up', 1872),
#  ('its', 1835),
#  ('about', 1808),
#  (':', 1788),
#  ('into', 1783),
#  ('them', 1777),
#  ('than', 1774),
#  ('can', 1765),
#  ('only', 1740),
#  ('other', 1683),
#  ('new', 1618),
#  ('some', 1602),
#  ('!', 1596),
#  ('could', 1594),
#  ('time', 1586),
#  ('these', 1557),
#  ('two', 1401),
#  ('may', 1395),
#  ('then', 1376),
#  ('do', 1357),
#  ('first', 1343),
#  ('any', 1334),
#  ('my', 1316),
#  ('now', 1303),
#  ('such', 1290),
#  ('like', 1287),
#  ('our', 1248),
#  ('over', 1227),
#  ('man', 1206),
#  ('me', 1181),
#  ('even', 1165),
#  ('most', 1150),
#  ('made', 1109),
#  ('after', 1058),
#  ('also', 1053),
#  ('did', 1036),
#  ('many', 1026),
#  ('before', 1008),
#  ('must', 1006),
#  ('af', 996),
#  ('through', 965),
#  ('back', 961),
#  ('years', 939),
#  ('where', 931),
#  ('much', 931),
#  ('your', 922),
#  ('way', 907),
#  ('well', 895),
#  ('down', 892),
#  ('because', 878),
#  ('should', 875),
#  ('just', 870),
#  ('each', 867),
#  ('those', 842),
#  ('people', 841),
#  ('how', 832),
#  ('too', 831),
#  ('little', 828),
#  ('mr.', 827),
#  ('good', 805),
#  ('very', 790),
#  ('world', 786),
#  ('make', 786),
#  ('still', 779),
#  ('own', 770),
#  ('state', 770),
#  ('see', 770),
#  ('men', 762),
#  ('work', 755),
#  ('here', 747),
#  ('long', 747),
#  ('get', 743),
#  ('between', 724),
#  ('both', 723),
#  ('life', 715),
#  ('being', 702),
#  ('never', 693),
#  ('under', 692),
#  ('same', 686),
#  ('know', 681),
#  ('day', 679),
#  ('another', 677),
#  ('while', 676),
#  ('us', 675),
#  ('might', 670),
#  ('great', 664),
#  ('last', 663),
#  ('old', 660),
#  ('off', 638),
#  ('year', 634),
#  ('come', 627),
#  ('against', 620),
#  ('since', 620),
#  ('came', 620),
#  ('go', 617),
#  ('right', 612),
#  ('used', 609),
#  ('three', 606),
#  ('take', 600),
#  ('himself', 600),
#  ('few', 600),
#  ('use', 587),
#  ('states', 585),
#  ('during', 581),
#  ('without', 579),
#  ('again', 574),
#  ('house', 569),
#  ('american', 567),
#  ('place', 565),
#  ('around', 561),
#  ('however', 548),
#  ('small', 542),
#  ('home', 537),
#  ('found', 534),
#  ('mrs.', 533),
#  ('1', 517),
#  ('thought', 517),
#  ('went', 504),
#  ('say', 502),
#  ('part', 498),
#  ('once', 498),
#  ('high', 492),
#  ('upon', 490),
#  ('every', 489),
#  ("don't", 489),
#  ('general', 483),
#  ('does', 482),
#  ('left', 478),
#  ('school', 478),
#  ('got', 478),
#  ('united', 468),
#  ('number', 467),
#  ('course', 465),
#  ('war', 463),
#  ('until', 460),
#  ('always', 457),
#  ('away', 456),
#  ('something', 448),
#  ('fact', 444),
#  ('2', 442),
#  ('though', 440),
#  ('water', 440),
#  ('put', 435),
#  ('less', 435),
#  ('think', 433),
#  ('hand', 431),
#  ('almost', 430),
#  ('public', 428),
#  ('enough', 427),
#  ('far', 425),
#  ('took', 424),
#  ('head', 422),
#  ('yet', 416),
#  ('system', 411),
#  ('nothing', 411),
#  ('better', 410),
#  ('set', 410),
#  ('government', 409),
#  ('end', 407),
#  ('told', 406),
#  ('night', 405),
#  ('why', 402),
#  ('eyes', 401),
#  ('look', 399),
#  ("didn't", 398),
#  ('going', 397),
#  ('find', 397),
#  ('called', 394),
#  ('knew', 394),
#  ('point', 393),
#  ('later', 393),
#  ('business', 391),
#  ('asked', 389),
#  ('next', 389),
#  ('group', 388),
#  ('young', 384),
#  ('give', 383),
#  ('room', 383),
#  ('let', 382),
#  ('toward', 381),
#  ('side', 380),
#  ('program', 378),
#  ('days', 377),
#  ('second', 373),
#  ('national', 372),
#  ('several', 372),
#  ('order', 372),
#  ('social', 372),
#  ('present', 371),
#  ('rather', 371),
#  ('given', 370),
#  ('face', 370),
#  ('form', 369),
#  ('possible', 369),
#  ('important', 368),
#  ('often', 368),
#  ('among', 367),
#  ('things', 367),
#  ('city', 366),
#  ('looked', 366),
#  ('early', 363),
#  ('per', 361),
#  ('large', 359),
#  ('john', 359),
#  ('white', 359),
#  ('within', 358),
#  ('big', 358),
#  ('president', 356),
#  ('become', 356),
#  ('four', 356),
#  ('case', 355),
#  ('need', 354),
#  ('felt', 354),
#  ('along', 352),
#  ('children', 351),
#  ('best', 350),
#  ('saw', 350),
#  ('church', 347),
#  ('ever', 341),
#  ('least', 341),
#  ('power', 341),
#  ('light', 333),
#  ('thing', 332),
#  ('seemed', 332),
#  ('development', 331),
#  ('interest', 328),
#  ('family', 328),
#  ('want', 327),
#  ('country', 323),
#  ('mind', 323),
#  ('area', 322),
#  ('members', 321),
#  ('others', 321),
#  ('turned', 320),
#  ('although', 320),
#  ('done', 318),
#  ('open', 318),
#  ('god', 316),
#  ('service', 313),
#  ('began', 312),
#  ('door', 312),
#  ("'", 311),
#  ('kind', 311),
#  ('certain', 311),
#  ('thus', 311),
#  ('different', 311),
#  ('sense', 310),
#  ('problem', 308),
#  ('whole', 308),
#  ('means', 306),
#  ('help', 306),
#  ('perhaps', 306),
#  ('matter', 304),
#  ('itself', 302),
#  ('york', 301),
#  ("it's", 301),
#  ('times', 299),
#  ('human', 299),
#  ('above', 296),
#  ('line', 296),
#  ('name', 293),
#  ('example', 292),
#  ('company', 290),
#  ('law', 289),
#  ('hands', 289),
#  ('action', 287),
#  ('show', 287),
#  ('history', 285),
#  ('either', 284),
#  ('3', 284),
#  ('feet', 283),
#  ('gave', 283),
#  ('five', 282),
#  ('whether', 282),
#  ('today', 281),
#  ('across', 281),
#  ('quite', 280),
#  ('anything', 280),
#  ('local', 278),
#  ('past', 278),
#  ('having', 278),
#  ('act', 278),
#  ('seen', 278),
#  ('taken', 276),
#  ('experience', 276),
#  ('body', 276),
#  ('death', 276),
#  ('really', 275),
#  ('car', 274),
#  ('words', 274),
#  ('week', 273),
#  ('word', 273),
#  ('field', 272),
#  ('already', 272),
#  ('half', 271),
#  ('themselves', 268),
#  ('shall', 268),
#  ("i'm", 268),
#  ('tell', 267),
#  ('together', 266),
#  ('period', 264),
#  ('keep', 264),
#  ('information', 264),
#  ('sure', 263),
#  ('held', 261),
#  ('probably', 260),
#  ('money', 260),
#  ('seems', 259),
#  ('free', 258),
#  ('college', 258),
#  ('behind', 257),
#  ('real', 256),
#  ('cannot', 256),
#  ('air', 256),
#  ('office', 253),
#  ('making', 253),
#  ('question', 253),
#  ('political', 253),
#  ('whose', 251),
#  ('brought', 250),
#  ('miss', 250),
#  ('moment', 246),
#  ('known', 245),
#  ('major', 245),
#  ('became', 245),
#  ('special', 244),
#  ('heard', 244),
#  ('street', 244),
#  ('available', 243),
#  ('boy', 242),
#  ('ago', 242),
#  ('result', 242),
#  ('study', 241),
#  ('position', 241),
#  ('problems', 241),
#  ('reason', 241),
#  ('economic', 240),
#  ('change', 239),
#  ('individual', 238),
#  ('south', 238),
#  ('am', 237),
#  ('job', 237),
#  ('society', 237),
#  ('board', 234),
#  ('areas', 234),
#  ('west', 233),
#  ('close', 233),
#  ('turn', 233),
#  ('love', 231),
#  ('true', 230),
#  ('seem', 229),
#  ('community', 228),
#  ('full', 228),
#  ('federal', 228),
#  ('force', 227),
#  ('wife', 226),
#  ('voice', 226),
#  ('wanted', 225),
#  ('center', 224),
#  ('woman', 224),
#  ('common', 223),
#  ('necessary', 222),
#  ('control', 222),
#  ('cost', 222),
#  ('age', 222),
#  ('future', 221),
#  ('front', 221),
#  ('sometimes', 221),
#  ('following', 220),
#  ('girl', 220),
#  ('land', 218),
#  ('six', 218),
#  ('clear', 217),
#  ('court', 216),
#  ('mother', 216),
#  ('music', 216),
#  ('able', 215),
#  ('department', 214),
#  ('party', 214),
#  ('feel', 214),
#  ('policy', 214),
#  ('town', 212),
#  ('level', 212),
#  ('short', 212),
#  ('further', 211),
#  ('university', 211),
#  ('effect', 211),
#  ('morning', 211),
#  ('total', 211),
#  ('stood', 211),
#  ('students', 211),
#  ('run', 210),
#  ('provide', 209),
#  ('figure', 209),
#  ('child', 209),
#  ('rate', 208),
#  ('art', 208),
#  ('outside', 208),
#  ('military', 207),
#  ('century', 207),
#  ('class', 207),
#  ('usually', 206),
#  ('north', 205),
#  ('leave', 205),
#  ('therefore', 205),
#  ('education', 204),
#  ('top', 203),
#  ('black', 203),
#  ('sound', 202),
#  ('4', 202),
#  ('hard', 201),
#  ('strong', 201),
#  ('type', 200),
#  ('value', 200),
#  ('play', 200),
#  ('various', 200),
#  ('surface', 200),
#  ('evidence', 199),
#  ('believe', 199),
#  ('washington', 198),
#  ('says', 198),
#  ('peace', 198),
#  ('modern', 198),
#  ('mean', 197),
#  ('lines', 197),
#  ('near', 197),
#  ('book', 197),
#  ('table', 197),
#  ('soon', 196),
#  ('minutes', 196),
#  ('red', 196),
#  ('road', 196),
#  ('women', 195),
#  ('gone', 195),
#  ('process', 195),
#  ('nor', 195),
#  ('started', 194),
#  ('personal', 194),
#  ('english', 194),
#  ('situation', 193),
#  ('america', 193),
#  ('alone', 193),
#  ('living', 193),
#  ('idea', 193),
#  ('longer', 193),
#  ('tax', 191),
#  ('private', 191),
#  ('cut', 191),
#  ('nature', 190),
#  ('third', 189),
#  ('finally', 189),
#  ('section', 188),
#  ('plan', 187),
#  ('call', 187),
#  ('million', 187),
#  ("that's", 187),
#  ('view', 186),
#  ('months', 186),
#  ('values', 186),
#  ('increase', 185),
#  ('greater', 185),
#  ('dr.', 185),
#  ('kept', 185),
#  ('needed', 185),
#  ('dark', 185),
#  ('ground', 185),
#  ('everything', 184),
#  ('secretary', 184),
#  ('space', 184),
#  ('pressure', 184),
#  ('basis', 183),
#  ('fire', 183),
#  ('father', 183),
#  ("i'll", 181),
#  ('complete', 181),
#  ('moved', 181),
#  ('spirit', 181),
#  ('required', 180),
#  ('expected', 180),
#  ('schools', 180),
#  ('union', 180),
#  ('wrote', 180),
#  ('return', 179),
#  ('late', 179),
#  ('particular', 179),
#  ('except', 179),
#  ('conditions', 179),
#  ('attention', 178),
#  ('east', 178),
#  ('recent', 177),
#  ('hope', 177),
#  ('support', 177),
#  ('brown', 176),
#  ('live', 176),
#  ('beyond', 175),
#  ('stage', 175),
#  ('else', 175),
#  ('dead', 174),
#  ('material', 174),
#  ("couldn't", 174),
#  ('forces', 173),
#  ('coming', 173),
#  ('nations', 173),
#  ('looking', 173),
#  ('taking', 173),
#  ('low', 173),
#  ('read', 173),
#  ('miles', 173),
#  ('inside', 173),
#  ('data', 173),
#  ('followed', 172),
#  ('heart', 172),
#  ('lost', 172),
#  ('feeling', 172),
#  ('1960', 172),
#  ('single', 172),
#  ('makes', 172),
#  ('person', 171),
#  ('industry', 171),
#  ('hours', 171),
#  ('cold', 171),
#  ('simply', 171),
#  ('instead', 170),
#  ('costs', 170),
#  ('hundred', 170),
#  ('move', 170),
#  ('tried', 170),
#  ('added', 169),
#  ('report', 169),
#  ('reached', 169),
#  ('basic', 169),
#  ("can't", 168),
#  ('developed', 168),
#  ('amount', 168),
#  ('including', 168),
#  ('hold', 167),
#  ('shown', 166),
#  ('equipment', 166),
#  ('river', 165),
#  ('religious', 164),
#  ('beginning', 164),
#  ('actually', 164),
#  ('sort', 164),
#  ('ten', 164),
#  ('son', 164),
#  ('terms', 163),
#  ('trying', 163),
#  ('st.', 163),
#  ('island', 163),
#  ('research', 163),
#  ('rest', 163),
#  ('friends', 162),
#  ('picture', 162),
#  ('indeed', 162),
#  ('getting', 162),
#  ('doing', 162),
#  ('central', 161),
#  ('&', 161),
#  ('especially', 161),
#  ('subject', 160),
#  ('difficult', 160),
#  ('wall', 160),
#  ('u.s.', 160),
#  ('simple', 160),
#  ('higher', 159),
#  ('defense', 159),
#  ('fine', 159),
#  ('walked', 159),
#  ('received', 158),
#  ('bring', 158),
#  ('building', 158),
#  ('pay', 157),
#  ('paper', 157),
#  ('training', 156),
#  ('floor', 156),
#  ('range', 156),
#  ('final', 155),
#  ('natural', 155),
#  ('market', 155),
#  ('growth', 154),
#  ('talk', 154),
#  ('start', 154),
#  ('england', 154),
#  ('written', 154),
#  ('meeting', 153),
#  ('international', 153),
#  ('suddenly', 153),
#  ("wasn't", 153),
#  ('story', 153),
#  ('answer', 152),
#  ('foreign', 152),
#  ('hall', 152),
#  ('police', 151),
#  ('considered', 151),
#  ("you're", 151),
#  ('hear', 151),
#  ('property', 150),
#  ('likely', 150),
#  ('care', 150),
#  ('similar', 150),
#  ('earth', 150),
#  ('sat', 150),
#  ('needs', 149),
#  ('results', 149),
#  ('entire', 149),
#  ('happened', 149),
#  ('cent', 148),
#  ('difference', 148),
#  ('working', 148),
#  ('passed', 148),
#  ('countries', 148),
#  ('purpose', 148),
#  ('production', 148),
#  ('hair', 148),
#  ('fall', 147),
#  ('labor', 147),
#  ('stand', 147),
#  ('stock', 147),
#  ('food', 147),
#  ('medical', 147),
#  ('william', 146),
#  ('issue', 146),
#  ('club', 145),
#  ('meet', 145),
#  ('using', 145),
#  ('committee', 145),
#  ('increased', 145),
#  ('particularly', 145),
#  ('below', 145),
#  ('thinking', 145),
#  ('whom', 144),
#  ('10', 144),
#  ('earlier', 144),
#  ('hour', 144),
#  ('knowledge', 144),
#  ('christian', 144),
#  ('letter', 144),
#  ('industrial', 143),
#  ('effort', 143),
#  ('congress', 143),
#  ('square', 143),
#  ('sent', 143),
#  ('boys', 143),
#  ('yes', 143),
#  ('trade', 142),
#  ('certainly', 142),
#  ('bad', 142),
#  ('due', 142),
#  ('deal', 142),
#  ('points', 142),
#  ('5', 142),
#  ('girls', 142),
#  ('moral', 142),
#  ('ideas', 142),
#  ('neither', 141),
#  ('method', 141),
#  ('involved', 141),
#  ('nearly', 141),
#  ('directly', 141),
#  ('paid', 141),
#  ('showed', 141),
#  ('throughout', 141),
#  ('try', 140),
#  ('decided', 140),
#  ('methods', 140),
#  ('ready', 140),
#  ('addition', 140),
#  ('reading', 140),
#  ('according', 139),
#  ('statement', 139),
#  ('questions', 139),
#  ('anyone', 139),
#  ('lay', 139),
#  ('color', 139),
#  ('french', 139),
#  ('weeks', 138),
#  ('remember', 138),
#  ('nation', 138),
#  ('blue', 138),
#  ('physical', 138),
#  ('member', 137),
#  ('comes', 137),
#  ('understand', 137),
#  ('southern', 137),
#  ('western', 137),
#  ('strength', 137),
#  ('size', 137),
#  ('administration', 136),
#  ('record', 136),
#  ('cases', 136),
#  ('population', 135),
#  ('services', 135),
#  ('appeared', 135),
#  ('programs', 135),
#  ('normal', 135),
#  ('temperature', 135),
#  ('volume', 134),
#  ('ran', 134),
#  ('county', 133),
#  ('direction', 133),
#  ('merely', 133),
#  ('continued', 133),
#  ('summer', 133),
#  ('friend', 133),
#  ('evening', 133),
#  ('maybe', 133),
#  ('literature', 133),
#  ('1961', 132),
#  ('influence', 132),
#  ('list', 132),
#  ('chance', 131),
#  ('district', 131),
#  ('led', 131),
#  ('met', 131),
#  ('provided', 131),
#  ('trouble', 131),
#  ('husband', 131),
#  ('concerned', 131),
#  ('average', 130),
#  ('works', 130),
#  ('month', 130),
#  ('army', 130),
#  ('association', 130),
#  ('opened', 130),
#  ('cause', 130),
#  ('stopped', 129),
#  ('wrong', 129),
#  ('generally', 129),
#  ('science', 129),
#  ('series', 129),
#  ('lead', 129),
#  ('hot', 129),
#  ('student', 129),
#  ('myself', 129),
#  ('piece', 129),
#  ('theory', 129),
#  ('sales', 128),
#  ('movement', 128),
#  ('ways', 128),
#  ('changes', 128),
#  ('planning', 128),
#  ("wouldn't", 128),
#  ('trial', 128),
#  ('direct', 128),
#  ('systems', 128),
#  ('step', 127),
#  ('meaning', 127),
#  ('effective', 127),
#  ('clearly', 127),
#  ('bed', 127),
#  ('freedom', 127),
#  ('fear', 127),
#  ('lot', 127),
#  ('treatment', 127),
#  ('beautiful', 127),
#  ('note', 127),
#  ('forms', 127),
#  ('george', 126),
#  ('hotel', 126),
#  ('former', 126),
#  ('truth', 126),
#  ('soviet', 126),
#  ('spring', 126),
#  ('consider', 126),
#  ('worked', 126),
#  ('ask', 125),
#  ("he's", 125),
#  ('plant', 125),
#  ('kennedy', 125),
#  ('carried', 125),
#  ('press', 125),
#  ('wide', 125),
#  ('placed', 125),
#  ("i've", 125),
#  ('respect', 125),
#  ("man's", 125),
#  ('somewhat', 125),
#  ('herself', 125),
#  ('numbers', 125),
#  ('easy', 124),
#  ('farm', 124),
#  ('running', 123),
#  ('aid', 123),
#  ('apparently', 123),
#  ('bill', 123),
#  ('groups', 123),
#  ('approach', 123),
#  ('game', 123),
#  ('recently', 123),
#  ('larger', 123),
#  ('lower', 123),
#  ('manner', 122),
#  ('organization', 122),
#  ('performance', 122),
#  ('immediately', 122),
#  ('feed', 122),
#  ('oh', 122),
#  ('degree', 121),
#  ('reaction', 121),
#  ('opportunity', 121),
#  ('daily', 121),
#  ('c', 121),
#  ('eye', 121),
#  ('blood', 121),
#  ('charge', 120),
#  ('stop', 120),
#  ('efforts', 120),
#  ('de', 120),
#  ('progress', 120),
#  ('couple', 120),
#  ('image', 119),
#  ('radio', 119),
#  ('technical', 119),
#  ('decision', 119),
#  ('fiscal', 119),
#  ('described', 119),
#  ('arms', 119),
#  ('window', 119),
#  ('religion', 119),
#  ('middle', 118),
#  ('additional', 118),
#  ('understanding', 118),
#  ('europe', 118),
#  ('main', 118),
#  ('british', 118),
#  ('based', 118),
#  ('character', 118),
#  ('determined', 118),
#  ('responsibility', 117),
#  ('aj', 117),
#  ('s.', 117),
#  ('account', 117),
#  ('march', 117),
#  ('gun', 117),
#  ('learned', 116),
#  ('test', 116),
#  ('green', 116),
#  ('steps', 116),
#  ('served', 116),
#  ('length', 116),
#  ('appear', 116),
#  ('writing', 116),
#  ('corner', 115),
#  ('forward', 115),
#  ('reported', 115),
#  ('activities', 115),
#  ('slowly', 115),
#  ('activity', 115),
#  ('types', 115),
#  ('horse', 115),
#  ('chief', 114),
#  ('latter', 114),
#  ('gives', 114),
#  ('straight', 114),
#  ('hit', 114),
#  ('plane', 114),
#  ('returned', 114),
#  ('lived', 114),
#  ('letters', 114),
#  ('quality', 114),
#  ('design', 114),
#  ('obviously', 114),
#  ('specific', 114),
#  ('j.', 113),
#  ('persons', 113),
#  ('audience', 113),
#  ('saying', 113),
#  ('serious', 113),
#  ('moving', 113),
#  ('justice', 113),
#  ('include', 113),
#  ('15', 113),
#  ('born', 113),
#  ('ones', 113),
#  ('doubt', 113),
#  ('pattern', 113),
#  ('operation', 112),
#  ('poor', 112),
#  ('staff', 112),
#  ('whatever', 112),
#  ('figures', 112),
#  ('shot', 112),
#  ('sun', 112),
#  ('stay', 112),
#  ('6', 112),
#  ('nuclear', 112),
#  ('function', 112),
#  ('choice', 111),
#  ('faith', 111),
#  ('cars', 111),
#  ('parts', 111),
#  ('obtained', 111),
#  ('pool', 111),
#  ('a.', 110),
#  ('heavy', 110),
#  ('waiting', 110),
#  ('speak', 110),
#  ('ball', 110),
#  ('standard', 110),
#  ('extent', 110),
#  ('30', 109),
#  ('income', 109),
#  ('ahead', 109),
#  ('corps', 109),
#  ('completely', 109),
#  ('lack', 109),
#  ('seven', 109),
#  ('deep', 109),
#  ("there's", 109),
#  ('wish', 109),
#  ('language', 109),
#  ('principle', 109),
#  ('democratic', 108),
#  ('established', 108),
#  ('products', 108),
#  ('visit', 108),
#  ('effects', 108),
#  ('growing', 108),
#  ('importance', 108),
#  ('indicated', 107),
#  ('leaders', 107),
#  ('division', 107),
#  ('firm', 107),
#  ('plans', 107),
#  ('pretty', 107),
#  ('distance', 107),
#  ('easily', 107),
#  ('expect', 107),
#  ('existence', 107),
#  ('price', 107),
#  ('attitude', 107),
#  ('analysis', 107),
#  ('stress', 107),
#  ('agreement', 106),
#  ('factors', 106),
#  ('scene', 106),
#  ('remained', 106),
#  ...]

# %% [markdown]
# ## Generate Random Text
#
# Let us generate some random text. We generate each time a random word, but shoose only from words that have been found in the corpus as a follower of the previous n-1 words. The probability to choose a word should correspond to the distribution in the corpus.

# %%
import random
import itertools
import re

def generate_rand(counts,start,n,maxln):
    if n > counts.maxlen:
        n = counts.maxlen
    words = start
    nrOfWords = len(start)
    if n > 1:
        last = words[-(n-1):]
    else:
        last = []
    while nrOfWords < 2*maxln:
        candidates = counts.getsuccessors(last)
        #stop if no successors are found or a nice ending was reached
        if len(candidates) == 0 or (nrOfWords > 0.9*maxln and words[-1] in ".!?"):
            break
        i = random.randrange(sum(candidates.values()))
        w = next(itertools.islice(candidates.elements(), i, None))
        words.append(w)
        nrOfWords += 1
        if n > 1:
            last = words[-(n-1):]
        else:
            last = []
     
    #Make the text look nice
    text = words[0].capitalize()
    for i in range(1,len(words)):
        word = words[i]
        if word[0] not in ".,;:!?)" and words[i-1] != '(':
            text += " "
        if words[i-1] == '.' or words[i-1] == '!' or words[i-1] == '?':
            text += word.capitalize()
        else:
            text += word
            
    return text

# %%
generate_rand(ngram_cnt,[],1,20)
# Out:
# "Morning `` access sansom skirt without too for the on, long-range u.s. scared switching,. Little feel it '' of a pieces her accordingly for, anyone secondary 15 ``, the had to fall wording danced important"

# %%
generate_rand(ngram_cnt,[],2,30)
# Out:
# "Economic and the piano lessons, and the most remarkable conviction that congress, robinson cut his hands worked perfectly free and a far better than interest of an infinite wisdom and as `` salami ''."

# %%
generate_rand(ngram_cnt,[],3,30)
# Out:
# ". The other side '' cropped up again in a bomber, each of her widowed mother, because excess body fat hampers his breathing. In what he hates, that is, i don't care how they're handled, mickey mantle and willie mays, the bbb has reported knowlton as saying: `` thanks '', rachel"

# %%
generate_rand(ngram_cnt,[],4,30)
# Out:
# "Flew beautifully '', said mr. skyros earnestly, `` just forget it ''. `` what were they doing here ''?? The selection of fellows from the latin american front, the first five minutes of this interview it is apparent to the therapist that `` everybody '', indicating to the linguist that this is,"

# %%
generate_rand(ngram_cnt,['you','may'],4,30)
# Out:
# "You may deduct reasonable wages you paid to him for scouting duty, most of us when we want to know what the dummies will do '' -- he interrupted himself, looking around."

# %% [markdown]
# ## Language Models
#
# Let us come to the language models: try to predict the next word. Here we have mainly to deal with sparsity and smoothing the model.
#
# First we read the test data. Note, that most models can deal with out of vocabulary words, but have to know how many unknown words we have! Thus we need to collect our entire vocabulary over test and training data as well.

# %%
#from nltk.corpus import webtext
#testtext = webtext.words()[:100000]
testtext = brown.words()[:10000]

vocab = set(testtext+brown.words())
vocab = set([w.lower() for w in vocab])

# %%
len(vocab)
# Out:
# 49815

# %% [markdown]
# We start with a basic class without smoothing.
#
# If we build an n-gram model we will base the prediction, of course, on n-grams. If less preceding text is givern smalle sequences will be used.

# %%
class langmodel:
    
    def __init__(self,vocab,counts,n):
        self.n = n
        self.rawcounts = counts
            
        
    def prob(self,w,prev):
        if self.n == 1:
            prev = []
        else:
            prev = prev[-self.n+1:]
        n_seq = self.rawcounts.getcount(prev+[w])
        if n_seq == 0:
            return 0
        else:
            return n_seq/self.rawcounts.getcount(prev)

# %%
unsmoothed2 = langmodel(vocab,ngram_cnt,2)

print(unsmoothed2.prob('testament',['the','old']))
print(unsmoothed2.prob('man',['the','old']))
print(unsmoothed2.prob('tower',['the','old']))
print(unsmoothed2.prob('twer',['the','ldpuio']))
# Out:
# 0.010606060606060607
# 0.10151515151515152
# 0
# 0

# %%
unsmoothed3 = langmodel(vocab,ngram_cnt,3)

print(unsmoothed3.prob('testament',['the','old']))
print(unsmoothed3.prob('man',['the','old']))
print(unsmoothed3.prob('tower',['the','old']))
print(unsmoothed3.prob('twer',['the','ldpuio']))
# Out:
# 0.02145922746781116
# 0.15450643776824036
# 0
# 0

# %%
class equal(langmodel):
    
    def __init__(self,vocab,counts):
            self.V = len(vocab) 
        
    def prob(self,w,prev):
        return 1/self.V

# %%
eq_model = equal(vocab,ngram_cnt)

print(eq_model.prob('testament',['the','old']))
print(eq_model.prob('man',['the','old']))
print(eq_model.prob('tower',['the','old']))
print(eq_model.prob('twer',['the','ldpuio']))
# Out:
# 2.007427481682224e-05
# 2.007427481682224e-05
# 2.007427481682224e-05
# 2.007427481682224e-05

# %% [markdown]
# ### Laplace Smoothing

# %%
class laplace(langmodel):
    
    def __init__(self,vocab,counts,n):
            self.n = n
            self.rawcounts = counts
            self.V = len(vocab) 
        
    def prob(self,w,prev):
        if self.n == 1:
            prev = []
        else:
            prev = prev[-self.n+1:]
        n_seq = self.rawcounts.getcount(prev+[w])
        n_prev = self.rawcounts.getcount(prev)
        return (n_seq + 1)/(n_prev+self.V)

# %%
laplace_model2 = laplace(vocab,ngram_cnt,2)

print(laplace_model2.prob('testament',['the','old']))
print(laplace_model2.prob('man',['the','old']))
print(laplace_model2.prob('tower',['the','old']))
print(laplace_model2.prob('twer',['the','ldpuio']))
# Out:
# 0.00015849430411094602
# 0.0013472015849430412
# 1.9811788013868253e-05
# 2.007427481682224e-05

# %%
laplace_model3 = laplace(vocab,ngram_cnt,3)

print(laplace_model3.prob('testament',['the','old']))
print(laplace_model3.prob('man',['the','old']))
print(laplace_model3.prob('tower',['the','old']))
print(laplace_model3.prob('twer',['the','ldpuio']))
# Out:
# 0.00011988491048593351
# 0.0007392902813299233
# 1.9980818414322252e-05
# 2.007427481682224e-05

# %% [markdown]
# ### Lidstone Smoothing

# %%
class lidstone(langmodel):
    
    def __init__(self,vocab,counts,n,labda):
            self.n = n
            self.rawcounts = counts
            self.lV = labda * len(vocab) 
            self.labda = labda
        
    def prob(self,w,prev):
        if self.n == 1:
            prev = []
        else:
            prev = prev[-self.n+1:]
        n_seq = self.rawcounts.getcount(prev+[w])
        n_prev = self.rawcounts.getcount(prev)
        return (n_seq + self.labda)/(n_prev+self.lV)

# %%
lidstone_model1 = lidstone(vocab,ngram_cnt,1,0.5)

print(lidstone_model1.prob('testament',['the','old']))
print(lidstone_model1.prob('man',['the','old']))
print(lidstone_model1.prob('tower',['the','old']))
print(lidstone_model1.prob('twer',['the','ldpuio']))
# Out:
# 2.508297575921704e-05
# 0.0010258511950337408
# 1.062837955899027e-05
# 4.251351823596108e-07

# %%
lidstone_model2 = lidstone(vocab,ngram_cnt,2,0.5)

print(lidstone_model2.prob('testament',['the','old']))
print(lidstone_model2.prob('man',['the','old']))
print(lidstone_model2.prob('tower',['the','old']))
print(lidstone_model2.prob('twer',['the','ldpuio']))
# Out:
# 0.0002933411557641537
# 0.0026400704018773834
# 1.955607705094358e-05
# 2.007427481682224e-05

# %%
lidstone_model3 = lidstone(vocab,ngram_cnt,3,0.5)

print(lidstone_model3.prob('testament',['the','old']))
print(lidstone_model3.prob('man',['the','old']))
print(lidstone_model3.prob('tower',['the','old']))
print(lidstone_model3.prob('twer',['the','ldpuio']))
# Out:
# 0.0002187705097352877
# 0.001451840655516
# 1.9888228157753426e-05
# 2.007427481682224e-05

# %% [markdown]
# ### Good Turing Discounting

# %%
class goodturing(langmodel):
    
    def __init__(self,vocab,counts,n):
            self.n = n
            self.rawcounts = counts
            self.V = len(vocab) 
            N_tg = 30 * [0]
            nrbg = 0
            nrtg = 0
            for (ng,cnt) in counts.allngrams(self.n):
                if len(ng) == self.n:
                    nrtg += 1
                    if cnt < 30: 
                        N_tg[cnt]+=1
            
            N_tg[0] = self.V**self.n - nrtg

            self.reestimated = []
            for i in range(10):
                self.reestimated.append((i + 1)*N_tg[i + 1]/N_tg[i])
            
            print("Reestimates:")
            for i in range(10):
                print(i, '\t', N_tg[i], '\t',self.reestimated[i])
                
            ##New (n-1)gram counts
            ##based on summing up all new values for each n-gram
            self.default = self.V * self.reestimated[0]
            self.adjcounts = ngramcounts()
            for (ng,cnt) in counts.allngrams(self.n-1):
                if len(ng) == self.n - 1:
                    successors = counts.getsuccessors(ng)
                    missing = self.V - len(successors)
                    adjustedcnt =  missing * self.reestimated[0]
                    for cnt in successors.values():
                        if cnt < 10:
                            cnt = self.reestimated[cnt]
                        adjustedcnt += cnt
                    self.adjcounts.add(ng,adjustedcnt)
        
    def prob(self,w,prev):
        prev = prev[-self.n+1:]
        n_seq = self.rawcounts.getcount(prev+[w])
        if n_seq < 10:
            n_seq = self.reestimated[n_seq]
        n_prev = self.adjcounts.getcount(prev)
        if n_prev == 0:
            n_prev = self.default
            
                        
        return n_seq/n_prev

# %%
gtmodel2 = goodturing(vocab,ngram_cnt,2)
# Out:
# Reestimates:
# 0 	 2481101319 	 0.00012938367229976068
# 1 	 321014 	 0.3166341654881096
# 2 	 50822 	 1.177875723112038
# 3 	 19954 	 2.0765761250877017
# 4 	 10359 	 3.1224056376098077
# 5 	 6469 	 4.055031689596538
# 6 	 4372 	 4.958600182982616
# 7 	 3097 	 6.111721020342267
# ['process-server']	6.761752417428388	1
# ['grimesby']	6.761752417428388	1
# ["roylott's"]	6.761752417428388	1
# ['speckled']	6.761752417428388	1
# ['incubi']	6.761752417428388	1
# ['masterly']	6.761752417428388	1
# ['beggary']	6.761752417428388	1
# ['hubris']	6.761752417428388	1
# ['plumbed']	6.761752417428388	1
# ['bathos']	6.761752417428388	1
# ['besmirched']	6.761752417428388	1
# ['extremis']	6.761752417428388	1
# ['pityingly']	6.761752417428388	1
# ['horoscope']	6.761752417428388	1
# ['sidle']	6.761752417428388	1
# ['bodhisattva']	6.761752417428388	1
# ['hors']	6.761752417428388	1
# ['yaws']	6.761752417428388	1
# ['fluke']	6.761752417428388	1
# ['bilharziasis']	6.761752417428388	1
# ['perelman']	6.761752417428388	1
# ['exhaling']	6.761752417428388	1
# ['aviary']	6.761752417428388	1
# ['olive-flushed']	6.761752417428388	1
# ['coral-colored']	6.761752417428388	1
# ['boucle']	6.761752417428388	1

# %%
print(gtmodel2.prob('testament',['the','old']))
print(gtmodel2.prob('man',['the','old']))
print(gtmodel2.prob('tower',['the','old']))
print(gtmodel2.prob('twer',['the','ldpuio']))
# Out:
# 0.015264043217479543
# 0.167332718912922
# 3.231361443113055e-07
# 2.0074274816822244e-05

# %%
gtmodel3 = goodturing(vocab,ngram_cnt,3)
# Out:
# Reestimates:
# 0 	 123617626530634 	 6.436193788293077e-09
# 1 	 795627 	 0.13678017462956887
# 2 	 54413 	 0.888206862330693
# 3 	 16110 	 1.7450031036623215
# 4 	 7028 	 2.736909504837792
# 5 	 3847 	 3.855471796204835
# 6 	 2472 	 4.652508090614886
# 7 	 1643 	 5.541083384053561
# 8 	 1138 	 6.825131810193322
# 9 	 863 	 7.404403244495945

# %%
print(gtmodel3.prob('testament',['the','old']))
print(gtmodel3.prob('man',['the','old']))
print(gtmodel3.prob('tower',['the','old']))
print(gtmodel3.prob('twer',['the','ldpuio']))
# Out:
# 0.037888259450229576
# 0.3537770245267795
# 6.324937465833516e-11
# 2.0074274816822244e-05

# %% [markdown]
# Note that the oov word following an oov word is more likely than a frequent word in an unseen n-gram!

# %% [markdown]
# ### Katz' Backoff

# %%
# Backs off only once, so wmorks only with bigrams
class backoff(langmodel):
    
    def __init__(self,vocab,counts,n):
            self.n = n
            self.rawcounts = counts
            self.V = len(vocab) 
            N_tg = 30 * [0]
            nrbg = 0
            nrtg = 0
            for (ng,cnt) in counts.allngrams(self.n):
                if len(ng) == self.n:
                    nrtg += 1
                    if cnt < 30: 
                        N_tg[cnt]+=1
            
            N_tg[0] = self.V**self.n - nrtg

            self.reestimated = []
            for i in range(10):
                self.reestimated.append((i + 1)*N_tg[i + 1]/N_tg[i])
                
            ##New (n-1)gram counts  and alpha's for adjusting backoff probabilities
            self.default = self.V * self.reestimated[0]
            self.adjcounts = ngramcounts()
            self.alpha = {}
            for (ng,cnt) in counts.allngrams(self.n - 1):
                if len(ng) == self.n - 1:
                    successors = counts.getsuccessors(ng)
                    missing = self.V - len(successors)
                    missingcnt =  missing * self.reestimated[0]
                    adjustedcnt = missingcnt
                    for cnt in successors.values():
                        if cnt < 10:
                            cnt = self.reestimated[cnt]
                        adjustedcnt += cnt
                    self.adjcounts.add(ng,adjustedcnt)
                    self.alpha[tuple(ng)] = missingcnt/adjustedcnt
        
    def prob(self,w,prev):
        prev = prev[-self.n+1:]
        n_seq = self.rawcounts.getcount(prev+[w])
        if n_seq > 0:
            if n_seq < 10:
                n_seq = self.reestimated[n_seq]
            n_prev = self.adjcounts.getcount(prev)
            if n_prev == 0:
                n_prev = self.default            
        
            return n_seq/n_prev
        else: #backoff to n-1 model
            if len(prev) > 1:
                prev = prev[1:]
            else:
                prev = []
            n_seq = 0.5 + self.rawcounts.getcount(prev+[w])
            n_prev = 0.5 * self.V + self.rawcounts.getcount(prev)
            alpha = self.alpha.get(tuple(prev+[w]),1)
            return alpha * n_seq/n_prev

# %%
bo_model2 = backoff(vocab,ngram_cnt,2)

# %% [markdown]
# How much probability mass is reserved for unknown bigrams?

# %%
print(bo_model2.alpha[('old',)])
print(bo_model2.alpha[('varicolored',)])
# Out:
# 0.01597488156631801
# 0.9531727655878103

# %%
print(bo_model2.prob('testament',['the','old']))
print(bo_model2.prob('man',['the','old']))
print(bo_model2.prob('tower',['the','old']))
print(bo_model2.prob('twer',['the','ldpuio']))
# Out:
# 0.015264043217479543
# 0.167332718912922
# 6.348456282355263e-06
# 4.251351823596108e-07

# %% [markdown]
# ## Evaluation
#
# We compute the perpexity of the test data to evaluate the models.

# %%
import math

def evaluate(model,text):
    entropy = 0
    for i in range(2,len(text)):
        entropy -= math.log(model.prob(text[i],text[i-2:i]))
    entropy /= (i-2)
    return math.exp(entropy)

# %%
evaluate(eq_model,testtext)
# Out:
# 49868.92559539385

# %% [markdown]
# Do you remember the vocabulary size?

# %%
models = {"Equal probabilities":eq_model,
          "Laplace - bigrams":laplace_model2,
          "Laplace - trigrams":laplace_model3,
          "Lidstone - monograms":lidstone_model1,
          "Lidstone - bigrams":lidstone_model2,
          "Good Turing - bigrams":gtmodel2,
          "Back-Off - bigrams":bo_model2}

# %%
print("{:<25} {:<15}".format('Model','Perplexity'))
print("{:<25} {:<15}".format('------','------------'))
for name in models: 
    p = evaluate(models[name],testtext)
    print ("{:<25} {:>9.2f}".format(name,p))
# Out:
# Model                     Perplexity
# ------                    ------------
# Equal probabilities        49868.93
# Laplace - bigrams           6567.25
# Laplace - trigrams         31718.68
# Lidstone - monograms        1454.27
# Lidstone - bigrams          4915.19
# Good Turing - bigrams       2067.65
# Back-Off - bigrams          1132.69

# %% [markdown]
# ## A simple application: Auto Completion
#
# Typical applicayions of language models combine two typs of information: the probability that a word is generated from a source, like speech signal, misspelled word, translation, etc. and the probability that the word follows the previous word, as computed by the language model.  A very easy application is autocompletion: we predict the next word, but it has to fit to what was already typed.
#
# For an efficient implementation we should should store our vocabulary in a prefix tree, in order to get fast access to all words starting with a given prefix. Here we will simply iterate throught the whole dictionary, ignoring efficiency issues.

# %%
def predict(model,words,beginning):
    maxprob = 0
    bestword = ""
    
    for w in vocab:
        if w.startswith(beginning):
            prob = model.prob(w,words)
            if prob > maxprob:
                maxprob = prob
                bestword = w
    return bestword

# %%
predict(bo_model2,['the','old'],'tow')
# Out:
# 'town'

# %%
predict(lidstone_model1,['the','old'],'tow')
# Out:
# 'toward'

# %%
predict(lidstone_model2,['the','old'],'tow')
# Out:
# 'town'

# %%
prev = ['old']
test = 'testament'
for i in range(len(test)+1):
    print(str(i)+' '+prev[0]+' '+test[:i]+'\t'+predict(lidstone_model1,prev,test[:i]))
 
print()

prev = ['old']
test = 'testament'
for i in range(len(test)+1):
    print(str(i)+' '+prev[0]+' '+test[:i]+'\t'+predict(bo_model2,prev,test[:i]))
# Out:
# 0 old 	the
# 1 old t	the
# 2 old te	tell
# 3 old tes	test
# 4 old test	test
# 5 old testa	testament
# 6 old testam	testament
# 7 old testame	testament
# 8 old testamen	testament
# 9 old testament	testament
#
# 0 old 	man
# 1 old t	testament
# 2 old te	testament
# 3 old tes	testament
# 4 old test	testament
# 5 old testa	testament
# 6 old testam	testament
# 7 old testame	testament
# 8 old testamen	testament
# 9 old testament	testament

# %% [markdown]
# ### Evaluation
#
# How much letters do we save typing on average? We just count. However, saving 1 letter is not helpfull and does not really save time. Maybe we should only count the longer savings.

# %%
def test_pred(model,word,prevwords):
    saving = 0
    for i in range(len(word)-1,-1,-1):
        if predict(model,prevwords,word[:i]) == word:
            saving = len(word) - i
        else:
            break
    return saving

# %%
test_pred(lidstone_model1,'testament',['old'])
# Out:
# 4

# %%
test_pred(gtmodel2,'testament',['old'])
# Out:
# 8

# %%
def eval_ac(model,text):
    count = 0
    saving = 0
    for i in range(2,len(text)):
            prec = [w.lower() for w in text[i-2:i]]
            word = text[i].lower()
            count += 1
            saving += test_pred(model,word,prec)
    return float(saving)/float(count)

# %%
print("{:<25} {:<15}".format('Model','Average saving'))
print("{:<25} {:<15}".format('------','------------'))
for name in models: 
    p = eval_ac(models[name],testtext[:1000])
    print ("{:<25} {:>9.2f}".format(name,p))
# Out:
# Model                     Average saving
# ------                    ------------
# Equal probabilities            0.54
# Laplace - bigrams              1.66
# Laplace - trigrams             0.99
# Lidstone - monograms           1.51
# Lidstone - bigrams             1.66
# Good Turing - bigrams          1.66
# Back-Off - bigrams             1.81

# %% [markdown]
# 1. Retrieve the POS tags for all words in the Brown corpus using nltk.corpus.brown.tagged_words() (including the test data!). For each word collect the 5 most frequent POS tags. Assign a list of these POS tags ordered by the frequency to each word.

# %%
print(len(nltk.corpus.brown.tagged_words()))
# Out:
# 1161192

# %%
data=nltk.corpus.brown.tagged_words()
tagged_word=nltk.corpus.brown.tagged_words()

# %%
from collections import defaultdict
word_tags = defaultdict(Counter)
for word, pos in brown.tagged_words():
    word_tags[word][pos] +=1

# %%
print(word_tags["go"])
print(word_tags["come"])
print(word_tags["apple"])
print(word_tags["time"])
# Out:
# Counter({'VB': 595, 'VB-NC': 8, 'NN': 1, 'VB-HL': 1})
# Counter({'VB': 395, 'VBN': 191, 'VB-NC': 2, 'VB-HL': 1})
# Counter({'NN': 7, 'NN-HL': 1})
# Counter({'NN': 1547, 'NN-HL': 8, 'VB': 1})

# %%
word_freq={}
for key in word_tags.keys():
    if len(word_tags[key])>5:
        word_freq[key]=list(word_tags[key])[:5]
    else:
        word_freq[key]=list(word_tags[key])

# %% [markdown]
# 2. Make classes of all words having the same sequence of possible POS tags, eventually, merge classes that consists of only a few infrequent words, e.g. by merging classes with the same set of labels, but withe a different order.

# %%
classes = {}
  
for key, value in word_freq.items():
    value=tuple(value)
    if value not in classes:
        classes[value] = [key]
    else:
        classes[value].append(key)

# %%
print(len(word_freq))
print(len(classes))
# Out:
# 56057
# 1581

# %%
print("Dictionary", str(classes))
# Out:
# Dictionary {('AT', 'AT-TL', 'AT-HL'): ['The'], ('NP-TL', 'NP'): ['Fulton', 'Atlanta', 'Grady', 'Miller', 'Beaumont', 'Lamar', 'Wise', 'Oklahoma', 'Massachusetts', 'York', 'Lao', 'America', 'Asia', 'Narragansett', 'Westfield', 'Essex', 'Michigan', 'Orleans', 'Miles', 'Pennsylvania', 'Columbia', 'Lafayette', 'Montgomery', 'Eastwick', 'Multnomah', 'Kiwanis', 'Beaverton', 'Florida', 'Columbus', 'Franklin', 'Louisiana', 'Minnesota', 'Ben', 'Babe', 'Ruth', 'Slocum', 'Mercer', 'Georgetown', 'Hogan', 'Warwick', 'Billiken', 'Arab', 'Brandenburg', 'Colorado', 'Perkins', 'Arlington', 'Philmont', 'Delaware', 'Drexel', 'Wellesley', 'Bailey', 'Westinghouse', 'Wabash', 'Dunbar', 'Jenks', 'Sterling', 'Elliott', 'McClellan', 'Delhi', 'Emory', 'Waddell', 'Leon', 'Cain', 'Piedmont', 'Burnside', 'Schuyler', 'Bess', 'Bond', 'Nevada', 'Beverly', 'Fletcher', 'Aurora', 'Guerin', 'Hardwicke-Etter', 'Moss', 'Gordin', 'Stacy', 'Mexico', 'Forsythe', 'Morocco', 'Cadillac', 'Hilton', 'Wilshire', 'Judson', 'Mackey', 'Aquinas', 'Leningrad', 'Kirov', 'Carolina', 'Taft-Hartley', 'Augusta', 'Boeing', 'Wales', 'Nassau', 'Goodbody', 'Graves', 'Carbondale', 'Tammany', 'Mekong', 'Matthew', 'Luke', 'Warsaw', 'Amsterdam', 'Korea', 'Yale', 'Dover', 'Hampshire', 'Kent', 'Gabrielle', 'Beth', 'Pleasant', 'Mayflower', 'Woodward', 'Schuylkill', 'Manchester', 'Vatican', 'Brahms', 'Pont', 'Timex', 'Dixieland', 'Britten', 'Virginian', 'Yalta', 'Beethoven', 'Hannah', 'Isaacs', 'Nagrin', 'Westchester', 'Phedre', 'Tartuffe', 'Scapin', 'Bourbon', 'Beale', 'Taras', 'Carmen', 'Sloan', 'Gloucester', 'Wollman', 'Moiseyev', 'Mackinac', 'Shawnee', 'Dana', 'Netherlands', 'Fawkes', 'Liverpool', 'Wesleyan', 'Nantucket', 'Tien', 'Buddha', 'Scheherazade', 'Giselle', 'Brumby', 'Valentine', 'Lullwater', 'Kodiak', 'Belmont', 'Adirondack', 'Winooski', 'Zion', 'Bryce', 'Merc', 'Salisbury', 'Merrimack', 'Fayette', 'Fairmont', 'Parkersburg', 'Copenhagen', 'Bavaria', 'Northfield', 'Curtiss', 'D.A.', 'Eichmann', 'Galway', 'Selkirk', 'Pembina', 'Witt', 'McKinley', 'Thayer', 'Amos', 'Spelman', 'Marmon', 'Malta', 'Marcellus', "Sant'", 'Agnese', 'Neptune', 'Frankfurt', 'Palestine', 'Venice', 'Sheridan', 'Rosenberg', 'Bengal', 'Manin', 'Grey', 'Savoy', 'Asheville', 'Meltzer', 'Saxon', 'Grande-Bretagne', 'Werther', 'Methuselah', 'Messiah', 'Leesona', 'Cobb', 'Christiana', 'Gonzales', 'Willcox', 'Gibbs', 'Carleton', 'Brookfield', 'Kikuyu', 'Mon-Khmer', 'Lublin', 'George-Barden', 'Burton', 'Dorset', 'Vail', 'Cubism', 'Boris', 'Beowulf', 'Cury', 'Neversink', 'Drew', 'Manassas', 'Izaak', 'Astor', 'Biscayne', 'Jolla', 'Dogtown', 'Sweeney', 'Quinzaine', 'Miyagi', 'Hanford', 'Ticonderoga', 'Cabrini'], ('NN-TL', 'NN'): ['County', 'Jury', 'Committee', 'Department', 'Welfare', 'Bar', 'Tax', 'Office', 'Hospital', 'Health', 'Party', 'Education', 'Taxation', 'School', 'Sulphur', 'Science', 'President', 'Council', 'Secretary', 'Delinquency', 'Attorney', 'Youth', 'Hotel', 'Group', 'Truck', 'Act', 'Company', 'War', 'Metal', 'Law', 'World', 'Circuit', 'Palm', 'Baseball', 'Point', 'Belt', 'Class', 'Opera', 'Debutante', 'Brain', 'Stock', 'Salvation', 'Center', 'Mortar', 'Chapel', 'Night', 'Walnut', 'Agriculture', 'Corporation', 'View', 'Traffic', 'Grocery', 'Maple', 'Fruit', 'Freedom', 'Convention', 'Space', 'Maintenance', 'Sanitation', 'Unit', 'Exchange', 'Treatment', 'Captain', 'Chicken', 'Mouse', 'Library', 'Workshop', 'Abolition', 'Family', 'Marriage', 'Anniversary', 'Radio', 'Tranquility', 'Aircraft', 'Folklore', 'Ace', 'Progress', 'Toll', 'Substance', 'Capital', 'Deal', 'Father', 'Car', 'Heaven', 'Bulletin', 'Legislation', 'Professor', 'Magazine', 'Holiness', 'Honey', 'Widow', 'Sesame', 'Program', 'Philosophy', 'Interpretation', 'Information', 'Victory', 'Silence', 'Rain', 'Milk', 'Gentleman', 'Artillery', 'Violence', 'Color', 'Corn', 'Physiologist', 'Promotion', 'Sacrifice', 'Criticism', 'Fear', 'Evangelism', 'Membership', 'Supper', 'Movement', 'Muscle', 'Builder', 'Leg', 'Ch.', 'Journalism', 'Scholarship', 'Safety', ...

# %% [markdown]
# 3. Write a function that computes the probabilities p( wi | ci) on test and training data.

# %%
word_freq={}
dict_new={}
for key in word_tags.keys():
    if len(word_tags[key])>5:
        word_freq[key]={A:N for (A,N) in [x for x in word_tags[key].items()][:4]}
    else:
        word_freq[key]=dict(word_tags[key])

for key,val in brown.tagged_words():
    if val in dict_new.keys():
        dict_new[val]+=1
    else:
        dict_new[val]=1
