# %% [markdown]
# # Prepare the data

# %% [markdown]
# ## Reading the text
#
# Load the data (see .zip file in Learnweb) into the environment of this notebook.
#
# If you are using google colab, you can upload the file as follows:

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8fc77f4-7db0-4371-bd11-1c8801251c35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8fc77f4-7db0-4371-bd11-1c8801251c35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movie_lines.tsv.zip to movie_lines.tsv.zip

# %% [markdown]
# Extract the contents of the zip file.

# %%
from zipfile import ZipFile
with ZipFile('movie_lines.tsv.zip', 'r') as zipObj:
   zipObj.extractall()

# %% [markdown]
# Read the file and extract the text.
#
# Note: reading the file with pandas or csv module does not work well, this file has a bad tsv format.

# %%
movie_lines = []
for line in open('movie_lines.tsv'):
    line = line.strip()
    while line[0] == '"' and line[-1] == '"':
        line = line[1:-1]
    movie_lines.append(line.split('\t')[-1])
movie_lines = [l.replace('""', '"').replace('  ', ' ') for l in movie_lines]
len(movie_lines)
# Out:
# 304713

# %% [markdown]
# ## Pre-processing
#
# Tokenization:

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TweetTokenizer

tokenizer = TweetTokenizer(preserve_case=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sentences = []
for line in movie_lines:
    line_sents = sent_tokenize(line)
    for sent in line_sents:
        sentences.append(tokenizer.tokenize(sent))
len(sentences)
# Out:
# 514866

# %%
sentences[76:81]
# Out:
# [['this', 'is', 'my', 'head'],
#  ['let', 'me', 'see', 'what', 'i', 'can', 'do', '.'],
#  ['gosh', 'if', 'only', 'we', 'could', 'find', 'kat', 'a', 'boyfriend', '...'],
#  ["that's", 'a', 'shame', '.'],
#  ['unsolved', 'mystery', '.']]

# %%
# total number of words
len([c for clist in sentences for c in clist])
# Out:
# 3829713

# %%
# number of tokens (unique words)
from collections import Counter

words = Counter(c for clist in sentences for c in clist)
len(words)
# Out:
# 61245

# %%
str(words)[:154]
# Out:
# "Counter({'.': 340514, 'you': 128297, '?': 110199, 'i': 103456, 'the': 99061, 'to': 80585, 'a': 71092, '-': 55093, '...': 51426, 'it': 47335, 'and': 45812,"

# %%
from flair.embeddings import FlairEmbeddings
from flair.data import Sentence

# init Flair forward and backwards embeddings
flair_embedding_forward = FlairEmbeddings('news-forward')
flair_embedding_backward = FlairEmbeddings('news-backward')

# %%
from flair.embeddings import StackedEmbeddings

# create a StackedEmbedding object that combines glove and forward/backward flair embeddings
stacked_embeddings = StackedEmbeddings([
                                        flair_embedding_forward,
                                        flair_embedding_backward,
                                       ])

# %%
words.items()
# Out:
# dict_items([('they', 12371), ('do', 22708), ('not', 19499), ('!', 37816), ('to', 80585), ('i', 103456), ('hope', 1020), ('so', 13375), ('.', 340514), ('she', 8700), ('okay', 4593), ('?', 110199), ("let's", 2455), ('go', 9910), ('wow', 267), ('-', 55093), ("you're", 13552), ('gonna', 4316), ('need', 3981), ('learn', 426), ('how', 10376), ('lie', 459), ('no', 19391), ("i'm", 22411), ('kidding', 403), ('you', 128297), ('know', 21623), ('sometimes', 716), ('just', 15815), ('become', 364), ('this', 24524), ('"', 9794), ('persona', 4), ('and', 45812), ("don't", 24296), ('quit', 328), ('like', 14982), ('my', 20794), ('fear', 273), ('of', 39324), ('wearing', 257), ('pastels', 2), ('the', 99061), ('real', 1848), ('what', 32205), ('good', 7326), ('stuff', 1136), ('figured', 327), ("you'd", 1483), ('get', 14142), ('eventually', 90), ('thank', 1928), ('god', 2394), ('if', 13173), ('had', 5549), ('hear', 1844), ('one', 10340), ('more', 4465), ('story', 926), ('about', 13985), ('your', 20928), ('coiffure', 3), ('...', 51426), ('me', 31843), ('endless', 17), ('blonde', 82), ('babble', 5), ('boring', 118), ('myself', 1222), ('crap', 215), ('listen', 1854), ('then', 6060), ('guillermo', 1), ('says', 1269), ('any', 4249), ('lighter', 22), ('look', 5920), ('an', 7015), ('extra', 162), ('on', 19531), ('90210', 1), ('always', 2583), ('been', 6509), ('selfish', 47), ('but', 17249), ("that's", 10950), ('all', 15365), ('say', 6114), ('well', 9811), ('never', 5454), ('wanted', 1813), ('out', 13326), ('with', 17233), ("'", 14519), ('did', 8666), ('was', 19688), ('looked', 453), ('for', 23392), ('back', 6201), ('at', 10702), ('party', 640), ('seemed', 192), ('be', 19407), ('occupied', 19), ('tons', 35), ('have', 21493), ('fun', 523), ('tonight', 1367), ('believe', 2546), ('we', 20687), ('share', 225), ('art', 231), ('instructor', 6), ('chastity', 9), ('looks', 1008), ('things', 2782), ('worked', 430), ('huh', 1658), ('hi', 973), ('who', 7135), ('knows', 1001), ("i've", 5307), ('ever', 2988), ('heard', 1454), ('her', 9298), ('is', 29210), ('that', 35349), ("she'd", 192), ('dip', 20), ('before', 2919), ('dating', 60), ('a', 71092), ('guy', 2461), ('smokes', 27), ('kind', 2072), ('likes', 275), ('pretty', 1336), ('ones', 342), ('lesbian', 20), ('found', 1273), ('picture', 440), ('jared', 2), ('leto', 4), ('in', 34093), ('drawers', 13), ('sure', 4386), ("she's", 2966), ('harboring', 5), ('same-sex', 3), ('tendencies', 6), ('workin', 78), ('it', 47335), ("doesn't", 2291), ('seem', 550), ('goin', 455), ('him', 12089), ('really', 4585), ('wanna', 953), ("can't", 6616), ('unless', 395), ('sister', 474), ('goes', 715), ("eber's", 1), ('deep', 270), ('conditioner', 7), ('every', 1884), ('two', 3675), ('days', 1100), ('use', 1150), ('blowdryer', 1), ('without', 1237), ('diffuser', 1), ('attachment', 5), ('hair', 446), ('sweet', 368), ('word', 925), ('as', 7846), ('gentleman', 131), ('counted', 23), ('help', 2638), ('cause', 1043), ('thug', 5), ('are', 16606), ('obviously', 179), ('failing', 16), ("aren't", 975), ('going', 8866), ('our', 4122), ('date', 371), ('got', 11494), ('something', 5442), ('mind', 1760), ('where', 5659), ('there', 10397), ("there's", 3894), ('someone', 1680), ('think', 10766), ('might', 1891), ('little', 4514), ('find', 2912), ('wench', 7), ('plan', 479), ('progressing', 3), ('forget', 1046), ('french', 240), ('because', 3351), ("it's", 18022), ('such', 1067), ('nice', 1816), ('want', 11054), ('though', 656), ('useful', 58), ('stores', 31), ('much', 3617), ('does', 2438), ('champagne', 81), ('cost', 240), ('chat', 59), ('life', 2877), ('point', 1009), ('head', 1222), ('right', 10007), ('see', 8213), ('ready', 885), ('quiz', 9), ("c'esc", 1), ('ma', 235), ('tete', 1), ('let', 3700), ('can', 11330), ('gosh', 77), ('only', 4070), ('could', 5814), ('kat', 37), ('boyfriend', 193), ('shame', 116), ('unsolved', 12), ('mystery', 74), ('used', 1347), ('popular', 80), ('when', 7170), ('started', 598), ('high', 607), ('school', 1055), ('sick', 656), (' ...

# %% [markdown]
# saw- count = 1558
# It has 2 meanings - to see , tool used for cutting
#
# teeth - count- 172 , one meaning

# %% [markdown]
# Store flair embeddings of required word from the sentences containing that word to another array

# %%
sentences_new = []
sent_array = []
for sentence in sentences:
  if('teeth' in sentence):
    sentences_new.append(' '.join(sentence))
    sent_array.append(sentence)

print(sentences_new[12])
# Out:
# what about his teeth ?

# %%
len(sentences_new)
# Out:
# 172

# %%
sentences_new2 = []
for sentence in sentences:
  if('saw' in sentence):
    sentences_new2.append(' '.join(sentence))

print(sentences_new2[1])
print(len(sentences_new2))
# Out:
# i saw your car .
# 1538

# %%
x = []
for i in sentences_new:
  sent = Sentence(i)
  stacked_embeddings.embed(sent)
  
  for token in sent:
    
    if token.text == 'teeth':  
      x.append(token.embedding)

# %%
len(x)
# Out:
# 172

# %%
emb_list = []
for i in sentences_new2:
  sent2 = Sentence(i)
  stacked_embeddings.embed(sent2)
  
  for token in sent2:
    
    if token.text == 'saw':  
      emb_list.append(token.embedding)

# %%
len(emb_list)
# Out:
# 1558

# %% [markdown]
# Calculating centroid of the lists

# %%
import torch

mean_teeth = torch.mean(torch.stack(x), dim=0)

print(mean_teeth)
# Out:
# tensor([-0.0015,  0.0007,  0.0061,  ..., -0.0007, -0.0403,  0.0016])

# %%
mean_saw = torch.mean(torch.stack(emb_list), dim=0)

print(mean_saw)
# Out:
# tensor([-0.0027, -0.0089, -0.0079,  ...,  0.0177, -0.0153,  0.0026])

# %% [markdown]
# Finding standard deviation btw similarities btw each embeddings and centroid

# %%
sim = []
cos = torch.nn.CosineSimilarity(dim = 0)
for i in x:
  sim.append(cos(i,mean_teeth))

std_teeth = torch.std(torch.stack(sim), dim=0)
print("STD of word teeth ",std_teeth)
# Out:
# STD of word teeth  tensor(0.0601)

# %%
sim2 = []

for i in emb_list:
  sim2.append(cos(i,mean_saw))

std_saw = torch.std(torch.stack(sim2), dim=0)
print("STD of word saw ",std_saw)
# Out:
# STD of word saw  tensor(0.0770)

# %% [markdown]
# Standard deviation of word having multiple meanings is more. Which is what we expect also as it will have different meanings in different contexts. But I expected the standard deviation difference to be higher.
